# %% [markdown]
# # Ifsoac y sus transformaciones

# %%
from ifsoac_2 import *

# %% [markdown]
# # Ejemplos MPL

# %%
rr = pd.read_csv("/Users/brend/Documents/Datos/DCL/RR/RRMNV_O2.txt", header=None).to_numpy().flatten()
gh = pd.read_csv("/Users/brend/Documents/Datos/Control/GH/GH240350VIGREP_O2.txt", header=None).to_numpy().flatten()

# %%
print(rr.size)
print(gh.size)
# Out:
# 164954
# 136664

# %%
# %time Ifsoac([rr, gh], {"cols_ds":2, "cmap_ds":"bmw"}).plot() 
# %time Ifsoac([rr, gh], {"cols_ds":2, "cmap_ds":"bmw"}).export_images(filename_prefix="rr_")
# Out:
# Wall time: 158 ms
# Wall time: 276 ms
# <table style="width:100%; text-align: center"><tbody><tr style="background-color:white"><td style="text-align: center"><b></b><br><br><img style="margin: auto; border:0px solid" src='data:image/png;base64,...'/></td><td style="text-align: center"><b></b><br><br><img style="margin: auto; border:0px solid" src='data:image/png;base64,...'/></td></tr><tr style="background-color:white"></tr></tbody></table>

# %%
#op_antipolar={"grafica":"ds", "transform":antipolar, "argv":{"delta_x":np.pi, "delta_y":np.pi}}
op_antipolar={"transform":antipolar, "cmap_ds":"CET_C1"}
# %time Ifsoac([lorenz, rossler], op_antipolar).plot()

# %%
logi = np.array(iterar(logistica, N=10000000, N0=0))
tienda = np.array(iterar(tent, N=10000000, N0=0, x0=.4))

# %time Ifsoac([logi, tienda], {"ventana_ds":1200}).plot()

# %%
op = op_antipolar.copy()
op.update({"ventana_ds":1200, "cols_ds":4, "cmap_ds":"bgy"})

#%time Ifsoac([logi[::c] for c in range(1, 5)], op).export_images()
# %time Ifsoac([logi[::c] for c in range(1, 5)], op).plot()

# %%
op = op_antipolar.copy()
op.update({"ventana_ds":1200, "cols_ds":4, "cmap_ds":"CET_C1"})

# %time Ifsoac([logi[::c] for c in range(1, 5)], op).plot()

# %%
# %time Ifsoac([tienda[::c] for c in range(1, 5)], op).plot()

# %%
op = {"transform":estereografica, "ventana_ds":1200}
# %time Ifsoac([logi, tienda], op).plot()

# %%
op = {"transform":antipolar, "ventana_ds":1200, "cols_ds":4, "cmap_ds":"CET_C1"}

# %time Ifsoac([lorenz, same_amount_bins(lorenz), rossler, same_amount_bins(rossler)], op).plot()

# %%
op1 = {"ventana_ds":300, "cols_ds":4}
op2 = {"transform":antipolar, "ventana_ds":1200, "cols_ds":4, "cmap_ds":"CET_C1"}

c = 6
# %time Ifsoac([lorenz[::c],same_amount_bins(lorenz)[::c],rossler[::c],same_amount_bins(rossler)[::c]], op1).plot()

# %%
c = 6
# %time Ifsoac([lorenz[::c],same_amount_bins(lorenz)[::c],rossler[::c],same_amount_bins(rossler)[::c]], op2).plot()

# %%
slogi = same_amount_bins(logi)
stienda = same_amount_bins(tienda)

op = {"ventana_ds":1200, "cmap_ds":"Hot"}

# %time Ifsoac([slogi[::i] for i in range(1, 5)], op).plot()

# %%
# %time Ifsoac([stienda[::i] for i in range(1, 5)], op).plot()

# %%
op1 = {"cols_ds":4, "nsides":1000, "ventana_ds":1200, "cmap_ds":"kgy"}

lor = lorenz_array(10000000)
slor = same_amount_bins(lor)
# %time Ifsoac([lor[::c] for c in range(1,9)], op1).plot()

# %%
op1 = {"cols_ds":4, "nsides":1000, "ventana_ds":1200, "cmap_ds":"CET_C1"}

lor = lorenz_array(10000000)
slor = same_amount_bins(lor)
# %time Ifsoac([lor[::c] for c in range(1,9)], op1).plot()

# %%
op1 = {"cols_ds":4, "nsides":1000, "ventana_ds":1200, "cmap_ds":"kgy"}
# %time Ifsoac([lor[::c] for c in range(1,40)], op1).plot()

# %%
# %time Ifsoac([slor[::c] for c in range(1,9)], op1).plot()

# %%
op2 = {"cols_ds":4, "nsides":1000, "transform":antipolar, "ventana_ds":1200, "cmap_ds":"bmw"}

# %time Ifsoac([lor[::c] for c in range(1,41,7)], op2).plot()

# %%
op2 = {"cols_ds":4, "nsides":1000, "transform":antipolar, "ventana_ds":1200, "cmap_ds":"bmw"}
# %time Ifsoac([slor[::c] for c in range(1,15)], op2).plot()

# %%
op2 = {"cols_ds":4, "nsides":1000, "transform":antipolar, "ventana_ds":1200, "cmap_ds":"bmw"}
# %time Ifsoac([slor[::c] for c in range(1,41)], op2).plot()

# %% [markdown]
# # Otras pruebas

# %%
# %time Ifsoac(op={"nsides":4, "p":3e-3, "cmap_ds":"bmw", "nrandom":10000000, "ventana_ds":1200}).plot()

# %%
op = {"transform":antipolar, "ventana_ds":1200, "cols_ds":4, "cmap_ds":"gray", "background_ds":None}

@jit(nopython=True)
def logistica(x):
    return 4*x*(1-x)

@jit(nopython=True)
def iterar(funcion=logistica, x0=0.3, N=10000000, N0=1000):
    ll = []
    for i in range(N0):
        y = funcion(x0)
        x0 = y
        #llogistica.append(y)
    # ya se generó una x0 "caótica"
    for i in range(N):
        y = funcion(x0)
        x0 = y
        ll.append(y)
    return ll


logi = np.array(iterar(logistica))
#%time Ifsoac(logi, op).export_images('testing', export_path="./carpeta sin título/")
# %time Ifsoac(logi, op).plot()

# %%
op = {"ventana_ds":1200, "cmap_ds":"Hot"}

#%time Ifsoac(logi, op).export_images()
# %time Ifsoac(logi, op).plot()

# %%
op = {"ventana_ds":1200, "cmap_ds":"Hot"}

#%time Ifsoac(lor, op).export_images()
# %time Ifsoac(lor, op).plot()

# %%
# %history
# Out:
# from ifsoac_2 import *
# rr = pd.read_csv("/Users/brend/Documents/Reposo/RR/RRMNV_O2.txt", header=None).to_numpy().flatten()
# gH = pd.read_csv("/Users/brend/Documents/Reposo/GH/GH240350VIGREP_O2.txt", header=None).to_numpy().flatten()
# print(rl.size)
# print(mg.size)
# from ifsoac_2 import *
# rr = pd.read_csv("/Users/brend/Documents/Reposo/RR/RRMNV_O2.txt", header=None).to_numpy().flatten()
# gh = pd.read_csv("/Users/brend/Documents/Reposo/GH/GH240350VIGREP_O2.txt", header=None).to_numpy().flatten()
# print(rr.size)
# print(gh.size)
# %time Ifsoac([rr, gh], {"cols_ds":2, "cmap_ds":"bmw"}).plot()
# %time Ifsoac([rr, gh], {"cols_ds":2, "cmap_ds":"bmw"}).export_images(filename_prefix="EMVIGOS2_")
# from ifsoac_2 import *
# rr = pd.read_csv("/Users/brend/Documents/R/RRVIGREP/RRMNV_O2.txt", header=None).to_numpy().flatten()
# gh = pd.read_csv("/Users/brend/Documents/Reposo/GH/GH240350VIGREP_O2.txt", header=None).to_numpy().flatten()
# print(rr.size)
# print(gh.size)
# %time Ifsoac([rr, gh], {"cols_ds":2, "cmap_ds":"bmw"}).plot()
# %time Ifsoac([rr, gh], {"cols_ds":2, "cmap_ds":"bmw"}).export_images(filename_prefix="EMVIGOS2_")
# %time Ifsoac([rr, gh], {"cols_ds":2, "cmap_ds":"bmw"}).plot()
# %time Ifsoac([rr, gh], {"cols_ds":2, "cmap_ds":"bmw"}).export_images(filename_prefix="EMVIGOS2_")
# rr = pd.read_csv("/Users/brend/Documents/R/RRVIGREP/RRMNV_O2.txt", header=None).to_numpy().flatten()
# gh = pd.read_csv("/Users/brend/Documents/R/GHVIGREP/GH240350VIGREP_O2.txt", header=None).to_numpy().flatten()
# print(rr.size)
# print(gh.size)
# %time Ifsoac([rr, gh], {"cols_ds":2, "cmap_ds":"bmw"}).plot()
# %time Ifsoac([rr, gh], {"cols_ds":2, "cmap_ds":"bmw"}).export_images(filename_prefix="EMVIGOS2_")
# %time Ifsoac([rr, gh], {"cols_ds":2, "cmap_ds":"bmw"}).plot()
# %time Ifsoac([rr, gh], {"cols_ds":2, "cmap_ds":"bmw"}).export_images(filename_prefix="rr_")
# %time Ifsoac([rr, gh], {"cols_ds":2, "cmap_ds":"bmw"}).plot()
# #%time Ifsoac([rr, gh], {"cols_ds":2, "cmap_ds":"bmw"}).export_images(filename_prefix="rr_")
# rr = pd.read_csv("/Users/brend/Documents/R/RRVIGREP/RRMNV_O2.txt", header=None).to_numpy().flatten()
# #gh = pd.read_csv("/Users/brend/Documents/R/GHVIGREP/GH240350VIGREP_O2.txt", header=None).to_numpy().flatten()
# print(rr.size)
# print(gh.size)
# %time Ifsoac([rr, gh], {"cols_ds":2, "cmap_ds":"bmw"}).plot()
# %time Ifsoac([rr, gh], {"cols_ds":2, "cmap_ds":"bmw"}).export_images(filename_prefix="rr_")
# rr = pd.read_csv("/Users/brend/Documents/Datos/DCL/RR/RRMNV_O2.txt", header=None).to_numpy().flatten()
# gh = pd.read_csv("/Users/brend/Documents/Datos/Control/GH/GH240350VIGREP_O2.txt", header=None).to_numpy().flatten()
# print(rr.size)
# print(gh.size)
# %time Ifsoac([rr, gh], {"cols_ds":2, "cmap_ds":"bmw"}).plot()
# %time Ifsoac([rr, gh], {"cols_ds":2, "cmap_ds":"bmw"}).export_images(filename_prefix="rr_")
# %time Ifsoac([rr,gh],op={"nsides":40, "p":.2, "cmap_ds":"bmw", "ventana_ds":600}).plot()
# rr = pd.read_csv("/Users/brend/Documents/Datos/DCL/RR/RRMNV_O2.txt", header=None).to_numpy().flatten()
# gh = pd.read_csv("/Users/brend/Documents/Datos/Control/GH/GH240350VIGREP_O2.txt", header=None).to_numpy().flatten()
# print(rr.size)
# print(gh.size)
# %time Ifsoac([rr, gh], {"cols_ds":2, "cmap_ds":"bmw"}).plot()
# %time Ifsoac([rr, gh], {"cols_ds":2, "cmap_ds":"bmw"}).export_images(filename_prefix="rr_")
# rr = pd.read_csv("/Users/brend/Documents/Reposo/RR/RRMNV_C4.txt", header=None).to_numpy().flatten()
# gh = pd.read_csv("/Users/brend/Documents/Reposo/GH/GH240350VIGREP_C4.txt", header=None).to_numpy().flatten()
# print(rr.size)
# print(gh.size)
# %time Ifsoac([rr, gh], {"cols_ds":2, "cmap_ds":"bmw"}).plot()
# %time Ifsoac([rr, gh], {"cols_ds":2, "cmap_ds":"bmw"}).export_images(filename_prefix="rr_")
# %time Ifsoac([rr,gh],op={"nsides":40, "p":.2, "cmap_ds":"bmw", "ventana_ds":600}).plot()
# from ifsoac_2 import *
# rr = pd.read_csv("/Users/brend/Documents/Reposo/RR/RRMNV_C4.txt", header=None).to_numpy().flatten()
# gh = pd.read_csv("/Users/brend/Documents/Reposo/GH/GH240350VIGREP_C4.txt", header=None).to_numpy().flatten()
# print(rr.size)
# print(gh.size)
# %time Ifsoac([rr, gh], {"cols_ds":2, "cmap_ds":"bmw"}).plot()
# %time Ifsoac([rr, gh], {"cols_ds":2, "cmap_ds":"bmw"}).export_images(filename_prefix="rr_")
# %time Ifsoac([rl, mg], {"ventana_ds":1200}).plot()
# #%time Ifsoac([logi, tienda], {"ventana_ds":1200}).plot()
# %time Ifsoac([rr, gh], {"ventana_ds":1200}).plot()
# #%time Ifsoac([logi, tienda], {"ventana_ds":1200}).plot()
# op1 = {"cols_ds":2, "nsides":500, "ventana_ds":1000, "cmap_ds":"CET_C1"}
#
# %time Ifsoac([same_amount_bins(rl)[::c] for c in range(1,2)], op1).plot()
# op1 = {"cols_ds":2, "nsides":500, "ventana_ds":1000, "cmap_ds":"CET_C1"}
#
# %time Ifsoac([same_amount_bins(rr)[::c] for c in range(1,2)], op1).plot()
# op1 = {"cols_ds":2, "nsides":5, "ventana_ds":1000, "cmap_ds":"CET_C1"}
#
# %time Ifsoac([same_amount_bins(rr)[::c] for c in range(1,2)], op1).plot()
# %time Ifsoac([rr,gh],op={"nsides":40, "p":.2, "cmap_ds":"bmw", "ventana_ds":600}).plot()
# from ifsoac_2 import *
# rr = pd.read_csv("/Users/brend/Documents/Reposo/RR/RRMNV_P4.txt", header=None).to_numpy().flatten()
# gh = pd.read_csv("/Users/brend/Documents/Reposo/GH/GH240350VIGREP_P4.txt", header=None).to_numpy().flatten()
# print(rr.size)
# print(gh.size)
# %time Ifsoac([rr, gh], {"cols_ds":2, "cmap_ds":"bmw"}).plot()
# %time Ifsoac([rr, gh], {"cols_ds":2, "cmap_ds":"bmw"}).export_images(filename_prefix="rr_")
# rr = pd.read_csv("/Users/brend/Documents/Datos reducidos/RRVIGREP/RRMNV_P4.txt", header=None).to_numpy().flatten()
# gh = pd.read_csv("/Users/brend/Documents/Reposo/GH/GH240350VIGREP_P4.txt", header=None).to_numpy().flatten()
# print(rr.size)
# print(gh.size)
# %time Ifsoac([rr, gh], {"cols_ds":2, "cmap_ds":"bmw"}).plot()
# %time Ifsoac([rr, gh], {"cols_ds":2, "cmap_ds":"bmw"}).export_images(filename_prefix="rr_")
# rr = pd.read_csv("/Users/brend/Documents/Datos/DCL/RR/RRVIGREP/RRMNV_P4.txt", header=None).to_numpy().flatten()
# gh = pd.read_csv("/Users/brend/Documents/Datos/Control/GH/GH240350VIGREP_P4", header=None).to_numpy().flatten()
# rr = pd.read_csv("/Users/brend/Documents/Datos/DCL/RR/RRVIGREP/RRMNV_P4.txt", header=None).to_numpy().flatten()
# gh = pd.read_csv("/Users/brend/Documents/Datos/Control/GH/GH240350VIGREP_P4.txt", header=None).to_numpy().flatten()
# rr = pd.read_csv("/Users/brend/Documents/Datos/DCL/RR/RRVIGREP/RRMNV_P4.txt", header=None).to_numpy().flatten()
# gh = pd.read_csv("/Users/brend/Documents/Datos/Control/GH/GH240350VIGREP_P4.txt", header=None).to_numpy().flatten()
# from ifsoac_2 import *
# rr = pd.read_csv("/Users/brend/Documents/Datos/DCL/RR/RRVIGREP/RRMNV_P4.txt", header=None).to_numpy().flatten()
# gh = pd.read_csv("/Users/brend/Documents/Datos/Control/GH/GH240350VIGREP_P4.txt", header=None).to_numpy().flatten()
# from ifsoac_2 import *
# rr = pd.read_csv("/Users/brend/Documents/Datos/DCL/RR/RRVIGREP/RRMNV_P4.txt", header=None).to_numpy().flatten()
# gh = pd.read_csv("/Users/brend/Documents/Datos/Control/GH/GH240350VIGREP_P4.txt", header=None).to_numpy().flatten()
# rr = pd.read_csv("/Users/brend/Documents/Datos/DCL/RR/RRMNV_P4.txt", header=None).to_numpy().flatten()
# gh = pd.read_csv("/Users/brend/Documents/Datos/Control/GH/GH240350VIGREP_P4.txt", header=None).to_numpy().flatten()
# %time Ifsoac([rr, gh], {"cols_ds":2, "cmap_ds":"CET_C1"}).plot()
# %history
